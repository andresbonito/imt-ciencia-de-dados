# %%
import pandas as pd

# %%
# %%capture
# !pip install yfinance

# %%
import yfinance as yf

# %%
path = 'https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/'

# %%
data = yf.download(['^BVSP', 'PETR4.SA', 'ITUB4.SA', 'BRL=X', 'BTC-USD'],'2019-01-01','2023-03-01')
data
# Out:
# [*********************100%***********************]  5 of 5 completed
#            Adj Close                                                 Close  \
#                BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP   BRL=X
# Date
# 2019-01-01    3.8800   3843.520020        NaN        NaN       NaN  3.8800
# 2019-01-02    3.8799   3943.409424  31.761539  11.060244   91012.0  3.8799
# 2019-01-03    3.7863   3836.741211  32.285164  11.331462   91564.0  3.7863
# 2019-01-04    3.7551   3857.717529  31.744343  11.363641   91841.0  3.7551
# 2019-01-05       NaN   3845.194580        NaN        NaN       NaN     NaN
# ...              ...           ...        ...        ...       ...     ...
# 2023-02-24    5.1362  23198.126953  25.652184  25.900000  105873.0  5.1362
# 2023-02-25       NaN  23175.375000        NaN        NaN       NaN     NaN
# 2023-02-26       NaN  23561.212891        NaN        NaN       NaN     NaN
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Rogerio-mack/IMT_Ciencia_de_Dados/main/data/lab_yahoo_q1.csv")
df
# Out:
#          Date   BRL=X      BTC-USD   ITUB4.SA   PETR4.SA    ^BVSP
# 0  2019-01-01  3.8800  3843.520020        NaN        NaN      NaN
# 1  2019-01-02  3.8799  3943.409424  31.761532  11.060242  91012.0
# 2  2019-01-03  3.7863  3836.741211  32.285156  11.331462  91564.0
# 3  2019-01-04  3.7551  3857.717529  31.744347  11.363639  91841.0
# 4  2019-01-05     NaN  3845.194580        NaN        NaN      NaN

# %%
df.shape
# Out:
# (5, 6)

# %%
df2 = data['Adj Close'].reset_index()
df2
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP
# 0    2019-01-01  3.8800   3843.520020        NaN        NaN       NaN
# 1    2019-01-02  3.8799   3943.409424  31.761539  11.060244   91012.0
# 2    2019-01-03  3.7863   3836.741211  32.285164  11.331462   91564.0
# 3    2019-01-04  3.7551   3857.717529  31.744343  11.363641   91841.0
# 4    2019-01-05     NaN   3845.194580        NaN        NaN       NaN
# ...         ...     ...           ...        ...        ...       ...
# 1515 2023-02-24  5.1362  23198.126953  25.652184  25.900000  105873.0
# 1516 2023-02-25     NaN  23175.375000        NaN        NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN        NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412  26.150000  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352  25.240000  104932.0
#
# [1520 rows x 6 columns]

# %%
df2.isnull().sum()
# Out:
# Date          0
# BRL=X       435
# BTC-USD       0
# ITUB4.SA    487
# PETR4.SA    487
# ^BVSP       487
# dtype: int64

# %%
# Q1

df2.sum()
# Out:
# <ipython-input-10-d02075958137>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.sum()
# BRL=X       5.341393e+03
# BTC-USD     3.565482e+07
# ITUB4.SA    2.757131e+04
# PETR4.SA    1.576586e+04
# ^BVSP       1.100975e+08
# dtype: float64

# %%
# Q2

df3 = pd.read_csv(path + 'lab_yahoo_q2.csv')
df3
# Out:
#          Date  day_gain
# 0  2019-01-02      True
# 1  2019-01-03     False
# 2  2019-01-04      True
# 3  2019-01-05     False
# 4  2019-01-06      True

# %%
df2
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP
# 0    2019-01-01  3.8800   3843.520020        NaN        NaN       NaN
# 1    2019-01-02  3.8799   3943.409424  31.761539  11.060244   91012.0
# 2    2019-01-03  3.7863   3836.741211  32.285164  11.331462   91564.0
# 3    2019-01-04  3.7551   3857.717529  31.744343  11.363641   91841.0
# 4    2019-01-05     NaN   3845.194580        NaN        NaN       NaN
# ...         ...     ...           ...        ...        ...       ...
# 1515 2023-02-24  5.1362  23198.126953  25.652184  25.900000  105873.0
# 1516 2023-02-25     NaN  23175.375000        NaN        NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN        NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412  26.150000  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352  25.240000  104932.0
#
# [1520 rows x 6 columns]

# %%
data_date = df2['Date']
data_date
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 1515   2023-02-24
# 1516   2023-02-25
# 1517   2023-02-26
# 1518   2023-02-27
# 1519   2023-02-28
# Name: Date, Length: 1520, dtype: datetime64[ns]

# %%
btc_usd = df2['BTC-USD']
btc_usd
# Out:
# 0        3843.520020
# 1        3943.409424
# 2        3836.741211
# 3        3857.717529
# 4        3845.194580
#             ...
# 1515    23198.126953
# 1516    23175.375000
# 1517    23561.212891
# 1518    23522.871094
# 1519    23147.353516
# Name: BTC-USD, Length: 1520, dtype: float64

# %%
#junção de duas colunas em uma nova tabela (sem o "axis" ele junta nas linhas as informações, e não nas colunas)

new_table = pd.concat([data_date, btc_usd], axis=1)
new_table
# Out:
#            Date       BTC-USD
# 0    2019-01-01   3843.520020
# 1    2019-01-02   3943.409424
# 2    2019-01-03   3836.741211
# 3    2019-01-04   3857.717529
# 4    2019-01-05   3845.194580
# ...         ...           ...
# 1515 2023-02-24  23198.126953
# 1516 2023-02-25  23175.375000
# 1517 2023-02-26  23561.212891
# 1518 2023-02-27  23522.871094
# 1519 2023-02-28  23147.353516
#
# [1520 rows x 2 columns]

# %%
day_gain = []

# %%
for i in range(1, df2.shape[0]):
  day_gain.append((df2.loc[i, 'BTC-USD'] - df2.loc[i - 1, 'BTC-USD']) > 0)

df_day_gain = pd.DataFrame()
df_day_gain['day_gain'] = day_gain

# %%
df_day_gain
# Out:
#       day_gain
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
# ...        ...
# 1514     False
# 1515     False
# 1516      True
# 1517     False
# 1518     False
#
# [1519 rows x 1 columns]

# %%
full_table = pd.concat([new_table, df_day_gain], axis=1)
full_table
# Out:
#            Date       BTC-USD day_gain
# 0    2019-01-01   3843.520020     True
# 1    2019-01-02   3943.409424    False
# 2    2019-01-03   3836.741211     True
# 3    2019-01-04   3857.717529    False
# 4    2019-01-05   3845.194580     True
# ...         ...           ...      ...
# 1515 2023-02-24  23198.126953    False
# 1516 2023-02-25  23175.375000     True
# 1517 2023-02-26  23561.212891    False
# 1518 2023-02-27  23522.871094    False
# 1519 2023-02-28  23147.353516      NaN
#
# [1520 rows x 3 columns]

# %%
df_day_gain.count()
# Out:
# day_gain    1519
# dtype: int64

# %%
true_false = df_day_gain['day_gain']
true_false
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1514    False
# 1515    False
# 1516     True
# 1517    False
# 1518    False
# Name: day_gain, Length: 1519, dtype: bool

# %%
true = true_false.sum()
true
# Out:
# 784

# %%
total = true_false.count()
total
# Out:
# 1519

# %%
false = total - true
false
# Out:
# 735

# %%
print(f'Q2 - True: {true} | False: {false}')
# Out:
# Q2 - True: 784 | False: 735

# %%
# Q3

df2
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP
# 0    2019-01-01  3.8800   3843.520020        NaN        NaN       NaN
# 1    2019-01-02  3.8799   3943.409424  31.761539  11.060244   91012.0
# 2    2019-01-03  3.7863   3836.741211  32.285164  11.331462   91564.0
# 3    2019-01-04  3.7551   3857.717529  31.744343  11.363641   91841.0
# 4    2019-01-05     NaN   3845.194580        NaN        NaN       NaN
# ...         ...     ...           ...        ...        ...       ...
# 1515 2023-02-24  5.1362  23198.126953  25.652184  25.900000  105873.0
# 1516 2023-02-25     NaN  23175.375000        NaN        NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN        NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412  26.150000  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352  25.240000  104932.0
#
# [1520 rows x 6 columns]

# %%
real = df2.melt(id_vars=['Date'], value_vars=['BRL=X', 'BTC-USD', 'ITUB4.SA', 'PETR4.SA', '^BVSP'], var_name='Ticket', value_name='Adj Close')
real
# Out:
#            Date Ticket    Adj Close
# 0    2019-01-01  BRL=X       3.8800
# 1    2019-01-02  BRL=X       3.8799
# 2    2019-01-03  BRL=X       3.7863
# 3    2019-01-04  BRL=X       3.7551
# 4    2019-01-05  BRL=X          NaN
# ...         ...    ...          ...
# 7595 2023-02-24  ^BVSP  105873.0000
# 7596 2023-02-25  ^BVSP          NaN
# 7597 2023-02-26  ^BVSP          NaN
# 7598 2023-02-27  ^BVSP  105711.0000
# 7599 2023-02-28  ^BVSP  104932.0000
#
# [7600 rows x 3 columns]

# %%
days = pd.to_datetime(real['Date']).dt.day_name()
days
# Out:
# 0         Tuesday
# 1       Wednesday
# 2        Thursday
# 3          Friday
# 4        Saturday
#           ...
# 7595       Friday
# 7596     Saturday
# 7597       Sunday
# 7598       Monday
# 7599      Tuesday
# Name: Date, Length: 7600, dtype: object

# %%
real['Days'] = pd.to_datetime(real['Date']).dt.day_name()
real
# Out:
#            Date Ticket    Adj Close       Days
# 0    2019-01-01  BRL=X       3.8800    Tuesday
# 1    2019-01-02  BRL=X       3.8799  Wednesday
# 2    2019-01-03  BRL=X       3.7863   Thursday
# 3    2019-01-04  BRL=X       3.7551     Friday
# 4    2019-01-05  BRL=X          NaN   Saturday
# ...         ...    ...          ...        ...
# 7595 2023-02-24  ^BVSP  105873.0000     Friday
# 7596 2023-02-25  ^BVSP          NaN   Saturday
# 7597 2023-02-26  ^BVSP          NaN     Sunday
# 7598 2023-02-27  ^BVSP  105711.0000     Monday
# 7599 2023-02-28  ^BVSP  104932.0000    Tuesday
#
# [7600 rows x 4 columns]

# %%
fridays = real[real['Days'] == 'Friday']
fridays
# Out:
#            Date Ticket    Adj Close    Days
# 3    2019-01-04  BRL=X       3.7551  Friday
# 10   2019-01-11  BRL=X       3.7079  Friday
# 17   2019-01-18  BRL=X       3.7489  Friday
# 24   2019-01-25  BRL=X       3.7698  Friday
# 31   2019-02-01  BRL=X       3.6428  Friday
# ...         ...    ...          ...     ...
# 7567 2023-01-27  ^BVSP  112502.0000  Friday
# 7574 2023-02-03  ^BVSP  108490.0000  Friday
# 7581 2023-02-10  ^BVSP  108150.0000  Friday
# 7588 2023-02-17  ^BVSP  109303.0000  Friday
# 7595 2023-02-24  ^BVSP  105873.0000  Friday
#
# [1085 rows x 4 columns]

# %%
real_friday = fridays[fridays['Ticket'] == 'BRL=X']
real_friday
# Out:
#            Date Ticket  Adj Close    Days
# 3    2019-01-04  BRL=X   3.755100  Friday
# 10   2019-01-11  BRL=X   3.707900  Friday
# 17   2019-01-18  BRL=X   3.748900  Friday
# 24   2019-01-25  BRL=X   3.769800  Friday
# 31   2019-02-01  BRL=X   3.642800  Friday
# ...         ...    ...        ...     ...
# 1487 2023-01-27  BRL=X   5.062745  Friday
# 1494 2023-02-03  BRL=X   5.049200  Friday
# 1501 2023-02-10  BRL=X   5.289500  Friday
# 1508 2023-02-17  BRL=X   5.216800  Friday
# 1515 2023-02-24  BRL=X   5.136200  Friday
#
# [217 rows x 4 columns]

# %%
real_friday_max = real_friday.max()
real_friday_max
# Out:
# Date         2023-02-24 00:00:00
# Ticket                     BRL=X
# Adj Close               5.828719
# Days                      Friday
# dtype: object

# %%
real_friday_largest = real_friday.nlargest(1, 'Adj Close')
real_friday_largest
# Out:
#           Date Ticket  Adj Close    Days
# 493 2020-05-08  BRL=X   5.828719  Friday

# %%
date_real_friday_largest = real_friday_largest['Date']

value_real_friday_largest = real_friday_largest['Adj Close']

# %%
print(f'Q3 - O maior valor é de 5.828719 e foi no dia 2020-05-08')
# Out:
# Q3 - O maior valor é de 5.828719 e foi no dia 2020-05-08

# %%
df2
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP
# 0    2019-01-01  3.8800   3843.520020        NaN        NaN       NaN
# 1    2019-01-02  3.8799   3943.409424  31.761539  11.060244   91012.0
# 2    2019-01-03  3.7863   3836.741211  32.285164  11.331462   91564.0
# 3    2019-01-04  3.7551   3857.717529  31.744343  11.363641   91841.0
# 4    2019-01-05     NaN   3845.194580        NaN        NaN       NaN
# ...         ...     ...           ...        ...        ...       ...
# 1515 2023-02-24  5.1362  23198.126953  25.652184  25.900000  105873.0
# 1516 2023-02-25     NaN  23175.375000        NaN        NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN        NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412  26.150000  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352  25.240000  104932.0
#
# [1520 rows x 6 columns]

# %%
df2.iloc[-4::]
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA  PETR4.SA     ^BVSP
# 1516 2023-02-25     NaN  23175.375000        NaN       NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN       NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412     26.15  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352     25.24  104932.0

# %%
df_days = df2

# %%
df_days['Days'] = pd.to_datetime(real['Date']).dt.day_name()
df_days
# Out:
#            Date   BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP  \
# 0    2019-01-01  3.8800   3843.520020        NaN        NaN       NaN
# 1    2019-01-02  3.8799   3943.409424  31.761539  11.060244   91012.0
# 2    2019-01-03  3.7863   3836.741211  32.285164  11.331462   91564.0
# 3    2019-01-04  3.7551   3857.717529  31.744343  11.363641   91841.0
# 4    2019-01-05     NaN   3845.194580        NaN        NaN       NaN
# ...         ...     ...           ...        ...        ...       ...
# 1515 2023-02-24  5.1362  23198.126953  25.652184  25.900000  105873.0
# 1516 2023-02-25     NaN  23175.375000        NaN        NaN       NaN
# 1517 2023-02-26     NaN  23561.212891        NaN        NaN       NaN
# 1518 2023-02-27  5.2078  23522.871094  25.322412  26.150000  105711.0
# 1519 2023-02-28  5.1997  23147.353516  25.412352  25.240000  104932.0
#
#            Days
# 0       Tuesday
# 1     Wednesday
# 2      Thursday
# 3        Friday
# 4      Saturday
# ...         ...
# ...

# %%
df_friday = df_days[df_days['Days'] == 'Friday']
df_friday
# Out:
#            Date     BRL=X       BTC-USD   ITUB4.SA   PETR4.SA     ^BVSP  \
# 3    2019-01-04  3.755100   3857.717529  31.744343  11.363641   91841.0
# 10   2019-01-11  3.707900   3687.365479  32.276573  11.487758   93658.0
# 17   2019-01-18  3.748900   3657.839355  32.328075  11.676231   96097.0
# 24   2019-01-25  3.769800   3599.765869        NaN        NaN       NaN
# 31   2019-02-01  3.642800   3487.945312  33.328148  11.860109   97861.0
# ...         ...       ...           ...        ...        ...       ...
# 1487 2023-01-27  5.062745  23078.728516  24.895340  25.620001  112502.0
# 1494 2023-02-03  5.049200  23449.322266  25.102566  24.790001  108490.0
# 1501 2023-02-10  5.289500  21651.183594  25.782093  26.719999  108150.0
# 1508 2023-02-17  5.216800  24565.601562  26.861343  26.440001  109303.0
# 1515 2023-02-24  5.136200  23198.126953  25.652184  25.900000  105873.0
#
#         Days
# 3     Friday
# 10    Friday
# 17    Friday
# 24    Friday
# 31    Friday
# ...      ...
# ...

# %%
new_df_friday = df_friday.pivot(index='Date', columns='Days', values='BTC-USD')
new_df_friday.reset_index()
# Out:
# Days       Date        Friday
# 0    2019-01-04   3857.717529
# 1    2019-01-11   3687.365479
# 2    2019-01-18   3657.839355
# 3    2019-01-25   3599.765869
# 4    2019-02-01   3487.945312
# ..          ...           ...
# 212  2023-01-27  23078.728516
# 213  2023-02-03  23449.322266
# 214  2023-02-10  21651.183594
# 215  2023-02-17  24565.601562
# 216  2023-02-24  23198.126953
#
# [217 rows x 2 columns]

# %%
# Q4

dolar_last_four = new_df_friday.iloc[-4::].reset_index()
dolar_last_four
# Out:
# Days       Date        Friday
# 0    2023-02-03  23449.322266
# 1    2023-02-10  21651.183594
# 2    2023-02-17  24565.601562
# 3    2023-02-24  23198.126953

# %%
mean_dolar_last_four = dolar_last_four['Friday'].mean()
mean_dolar_last_four
# Out:
# 23216.05859375

# %%
print(f'Q4 - A média da cotação do dólar dos ultimos 4 valores é de USD {mean_dolar_last_four :.2f}')
# Out:
# Q4 - A média da cotação do dólar dos ultimos 4 valores é de USD 23216.06

# %%
lista_moedas = ['BTC-USD', 'ITUB4.SA', 'PETR4.SA']
lista_moedas2 = ['BRL=X', 'BTC-USD', 'ITUB4.SA', 'PETR4.SA', '^BVSP']

for c in lista_moedas:
  df_friday[c] = df_friday[c] * df_friday['BRL=X']

df_friday
# Out:
# <ipython-input-116-ae8a0fba8c0e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_friday[c] = df_friday[c] * df_friday['BRL=X']
#            Date     BRL=X        BTC-USD    ITUB4.SA  PETR4.SA     ^BVSP  \
# 3    2019-01-04  3.755100   54396.811133  447.619870  0.930720   91841.0
# 10   2019-01-11  3.707900   50695.828209  443.755201  0.917381   93658.0
# 17   2019-01-18  3.748900   51408.191451  454.346878  0.953167   96097.0
# 24   2019-01-25  3.769800   51157.682600         NaN       NaN       NaN
# 31   2019-02-01  3.642800   46285.008191  442.264273  0.914151   97861.0
# ...         ...       ...            ...         ...       ...       ...
# 1487 2023-01-27  5.062745  591539.842589  638.102115  3.814257  112502.0
# ...

# %%
for i in lista_moedas2:
  df_friday[c] = df_friday[c] / df_friday[c].max()

df_friday
# Out:
# <ipython-input-117-e407f506ff05>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_friday[c] = df_friday[c] / df_friday[c].max()
#            Date     BRL=X        BTC-USD    ITUB4.SA  PETR4.SA     ^BVSP  \
# 3    2019-01-04  3.755100   54396.811133  447.619870  0.178415   91841.0
# 10   2019-01-11  3.707900   50695.828209  443.755201  0.175858   93658.0
# 17   2019-01-18  3.748900   51408.191451  454.346878  0.182718   96097.0
# 24   2019-01-25  3.769800   51157.682600         NaN       NaN       NaN
# 31   2019-02-01  3.642800   46285.008191  442.264273  0.175239   97861.0
# ...         ...       ...            ...         ...       ...       ...
# 1487 2023-01-27  5.062745  591539.842589  638.102115  0.731177  112502.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(15,4))

df_friday = df_friday.set_index('Date')

for c in ['BRL=X', 'BTC-USD', 'ITUB4.SA', 'PETR4.SA', '^BVSP']:
  plt.plot(df_friday[c], label=c)

plt.title('Friday Adj Close', fontsize=14, weight='bold')
plt.xlabel('Date')
plt.ylabel('Normalized Values')
plt.legend()

plt.show()

# %% [markdown]
# #Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# #Arquivos

# %%
path = 'https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/'

company_before = 'company_before.csv'
company_fev = 'company_fev.csv'
company_mar = 'company_mar.csv'

# %% [markdown]
# ## Primeiro

# %%
df_before = pd.read_csv(path + company_before)
df_before
# Out:
#         id           Setor       Sexo       Grau_Instrucao  Idade  \
# 0        1        Operacao  Masculino    Superior Completo     54
# 1        2              RH  Masculino            Doutorado     52
# 2        3              RH  Masculino             Mestrado     54
# 3        4      Financeiro   Feminino             Mestrado     32
# 4        5              RH  Masculino  Superior Incompleto     34
# ...    ...             ...        ...                  ...    ...
# 1490  1516  Administrativo   Feminino  Superior Incompleto     39
# 1491  1517              RH  Masculino    Superior Completo     34
# 1492  1518        Operacao  Masculino    Superior Completo     37
# 1493  1519        Operacao   Feminino    Superior Completo     57
# 1494  1520              RH   Feminino    Superior Completo     46
#
#       Anos_Experiencia Estado      Salario
# 0                   12     SP  2708.410161
# 1                   12     SP  8321.204000
# ...

# %% [markdown]
# ## Segundo

# %%
df_fev = pd.read_csv(path + company_fev)
df_fev
# Out:
#      id           Setor       Sexo       Grau_Instrucao  Idade  \
# 0  1390  Administrativo   Feminino  Superior Incompleto     55
# 1  1407       Marketing  Masculino    Superior Completo     40
# 2  1347  Administrativo   Feminino             Mestrado     35
# 3  1123        Operacao  Masculino             Mestrado     45
# 4  1042  Administrativo   Feminino  Superior Incompleto     43
# 5   107      Financeiro  Masculino    Superior Completo     54
# 6  1148       Marketing  Masculino    Superior Completo     61
# 7  1239  Administrativo  Masculino            Doutorado     72
# 8    97       Marketing   Feminino    Superior Completo     47
# 9   114        Operacao   Feminino    Superior Completo     52
#
#    Anos_Experiencia Estado       Salario
# 0                11     SP   1999.616745
# 1                17     SP   5139.437521
# 2                 8     SP   6883.379725
# 3                16     SP   6386.825060
# 4                16     BH   1877.931320
# ...

# %% [markdown]
# ## Terceiro

# %%
df_mar = pd.read_csv(path + company_mar)
df_mar
# Out:
#    Sex       Grau_Instrucao  Experiencia  Idade Estado       Salario  \
# 0    M    Superior Completo           11     56     SP   3722.984809
# 1    F    Superior Completo            9     31     RJ  10290.856780
# 2    F  Superior Incompleto           12     53     SP   3583.467000
# 3    M            Doutorado           16     45     BH  10588.027760
# 4    F  Superior Incompleto           15     46     SP   1995.308000
# 5    M    Superior Completo           17     41     SP   2182.034262
# 6    M    Superior Completo           13     51     SP   8980.024053
# 7    F  Superior Incompleto           16     43     RJ   5877.276943
# 8    M    Superior Completo           10     58     BH   6538.568000
# 9    M    Superior Completo           16     44     RJ   2625.620436
# 10   M    Superior Completo            8     35     SP   4087.606289
# 11   M             Mestrado           14     50     SP   6294.245630
# 12   M    Superior Completo            8     63     SP   2769.916194
# ...

# %% [markdown]
# #Dropando elementos

# %% [markdown]
# ## Dropa id do primeiro arquivo

# %%
df1 = df_before.drop(columns='id')
df1
# Out:
#                Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0           Operacao  Masculino    Superior Completo     54                12
# 1                 RH  Masculino            Doutorado     52                12
# 2                 RH  Masculino             Mestrado     54                12
# 3         Financeiro   Feminino             Mestrado     32                 9
# 4                 RH  Masculino  Superior Incompleto     34                 8
# ...              ...        ...                  ...    ...               ...
# 1490  Administrativo   Feminino  Superior Incompleto     39                15
# 1491              RH  Masculino    Superior Completo     34                 8
# 1492        Operacao  Masculino    Superior Completo     37                13
# 1493        Operacao   Feminino    Superior Completo     57                10
# 1494              RH   Feminino    Superior Completo     46                15
#
#      Estado      Salario
# ...

# %% [markdown]
# ## Dropa id do segundo arquivo

# %%
df2 = df_fev.drop(columns='id')
df2
# Out:
#             Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0  Administrativo   Feminino  Superior Incompleto     55                11
# 1       Marketing  Masculino    Superior Completo     40                17
# 2  Administrativo   Feminino             Mestrado     35                 8
# 3        Operacao  Masculino             Mestrado     45                16
# 4  Administrativo   Feminino  Superior Incompleto     43                16
# 5      Financeiro  Masculino    Superior Completo     54                12
# 6       Marketing  Masculino    Superior Completo     61                 9
# 7  Administrativo  Masculino            Doutorado     72                 7
# 8       Marketing   Feminino    Superior Completo     47                15
# 9        Operacao   Feminino    Superior Completo     52                13
#
#   Estado       Salario
# 0     SP   1999.616745
# 1     SP   5139.437521
# 2     SP   6883.379725
# 3     SP   6386.825060
# ...

# %%
df_mar
# Out:
#    Sex       Grau_Instrucao  Experiencia  Idade Estado       Salario  \
# 0    M    Superior Completo           11     56     SP   3722.984809
# 1    F    Superior Completo            9     31     RJ  10290.856780
# 2    F  Superior Incompleto           12     53     SP   3583.467000
# 3    M            Doutorado           16     45     BH  10588.027760
# 4    F  Superior Incompleto           15     46     SP   1995.308000
# 5    M    Superior Completo           17     41     SP   2182.034262
# 6    M    Superior Completo           13     51     SP   8980.024053
# 7    F  Superior Incompleto           16     43     RJ   5877.276943
# 8    M    Superior Completo           10     58     BH   6538.568000
# 9    M    Superior Completo           16     44     RJ   2625.620436
# 10   M    Superior Completo            8     35     SP   4087.606289
# 11   M             Mestrado           14     50     SP   6294.245630
# 12   M    Superior Completo            8     63     SP   2769.916194
# ...

# %%
df3 = df_mar.rename(columns={'Sex':'Sexo', 'Departamento':'Setor', 'Experiencia':'Anos_Experiencia'})
df3
# Out:
#    Sexo       Grau_Instrucao  Anos_Experiencia  Idade Estado       Salario  \
# 0     M    Superior Completo                11     56     SP   3722.984809
# 1     F    Superior Completo                 9     31     RJ  10290.856780
# 2     F  Superior Incompleto                12     53     SP   3583.467000
# 3     M            Doutorado                16     45     BH  10588.027760
# 4     F  Superior Incompleto                15     46     SP   1995.308000
# 5     M    Superior Completo                17     41     SP   2182.034262
# 6     M    Superior Completo                13     51     SP   8980.024053
# 7     F  Superior Incompleto                16     43     RJ   5877.276943
# 8     M    Superior Completo                10     58     BH   6538.568000
# 9     M    Superior Completo                16     44     RJ   2625.620436
# 10    M    Superior Completo                 8     35     SP   4087.606289
# ...

# %%
df3.Sexo = df3.Sexo.replace('M', 'Masculino')
df3
# Out:
#          Sexo       Grau_Instrucao  Anos_Experiencia  Idade Estado  \
# 0   Masculino    Superior Completo                11     56     SP
# 1           F    Superior Completo                 9     31     RJ
# 2           F  Superior Incompleto                12     53     SP
# 3   Masculino            Doutorado                16     45     BH
# 4           F  Superior Incompleto                15     46     SP
# 5   Masculino    Superior Completo                17     41     SP
# 6   Masculino    Superior Completo                13     51     SP
# 7           F  Superior Incompleto                16     43     RJ
# 8   Masculino    Superior Completo                10     58     BH
# 9   Masculino    Superior Completo                16     44     RJ
# 10  Masculino    Superior Completo                 8     35     SP
# 11  Masculino             Mestrado                14     50     SP
# 12  Masculino    Superior Completo                 8     63     SP
# ...

# %%
df3.Sexo = df3.Sexo.replace('F', 'Feminino')
df3
# Out:
#          Sexo       Grau_Instrucao  Anos_Experiencia  Idade Estado  \
# 0   Masculino    Superior Completo                11     56     SP
# 1    Feminino    Superior Completo                 9     31     RJ
# 2    Feminino  Superior Incompleto                12     53     SP
# 3   Masculino            Doutorado                16     45     BH
# 4    Feminino  Superior Incompleto                15     46     SP
# 5   Masculino    Superior Completo                17     41     SP
# 6   Masculino    Superior Completo                13     51     SP
# 7    Feminino  Superior Incompleto                16     43     RJ
# 8   Masculino    Superior Completo                10     58     BH
# 9   Masculino    Superior Completo                16     44     RJ
# 10  Masculino    Superior Completo                 8     35     SP
# 11  Masculino             Mestrado                14     50     SP
# 12  Masculino    Superior Completo                 8     63     SP
# ...

# %%
df3.Setor = df3.Setor.replace('Recursos Humanos', 'RH')
df3
# Out:
#          Sexo       Grau_Instrucao  Anos_Experiencia  Idade Estado  \
# 0   Masculino    Superior Completo                11     56     SP
# 1    Feminino    Superior Completo                 9     31     RJ
# 2    Feminino  Superior Incompleto                12     53     SP
# 3   Masculino            Doutorado                16     45     BH
# 4    Feminino  Superior Incompleto                15     46     SP
# 5   Masculino    Superior Completo                17     41     SP
# 6   Masculino    Superior Completo                13     51     SP
# 7    Feminino  Superior Incompleto                16     43     RJ
# 8   Masculino    Superior Completo                10     58     BH
# 9   Masculino    Superior Completo                16     44     RJ
# 10  Masculino    Superior Completo                 8     35     SP
# 11  Masculino             Mestrado                14     50     SP
# 12  Masculino    Superior Completo                 8     63     SP
# ...

# %%
df3 = df3[['Setor', 'Sexo', 'Grau_Instrucao', 'Idade', 'Anos_Experiencia', 'Estado', 'Salario']]
df3
# Out:
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     56                11
# 1   Administrativo   Feminino    Superior Completo     31                 9
# 2               RH   Feminino  Superior Incompleto     53                12
# 3         Operacao  Masculino            Doutorado     45                16
# 4   Administrativo   Feminino  Superior Incompleto     46                15
# 5       Financeiro  Masculino    Superior Completo     41                17
# 6         Operacao  Masculino    Superior Completo     51                13
# 7         Operacao   Feminino  Superior Incompleto     43                16
# 8               RH  Masculino    Superior Completo     58                10
# 9         Operacao  Masculino    Superior Completo     44                16
# 10       Marketing  Masculino    Superior Completo     35                 8
# ...

# %%
df_df = pd.concat([df1, df2, df3])
df_df
# Out:
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     54                12
# 1               RH  Masculino            Doutorado     52                12
# 2               RH  Masculino             Mestrado     54                12
# 3       Financeiro   Feminino             Mestrado     32                 9
# 4               RH  Masculino  Superior Incompleto     34                 8
# ..             ...        ...                  ...    ...               ...
# 10       Marketing  Masculino    Superior Completo     35                 8
# 11       Marketing  Masculino             Mestrado     50                14
# 12  Administrativo  Masculino    Superior Completo     63                 8
# 13  Administrativo  Masculino    Superior Completo     61                 9
# 14      Financeiro   Feminino            Doutorado     36                 8
#
#    Estado       Salario
# 0      SP   2708.410161
# ...

# %%
soma_salario = df_df.groupby('Setor').sum()
tabela_salario = soma_salario.drop(columns=['Idade', 'Anos_Experiencia']).reset_index()
tabela_salario
# Out:
#             Setor       Salario
# 0  Administrativo  2.248535e+06
# 1      Financeiro  8.967006e+05
# 2       Marketing  9.669023e+05
# 3        Operacao  3.545110e+06
# 4              RH  1.048478e+06

# %%
tabela_salario.sum()
# Out:
# Setor      AdministrativoFinanceiroMarketingOperacaoRH
# Salario                                 8705724.860367
# dtype: object

# %%
df_df
# Out:
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     54                12
# 1               RH  Masculino            Doutorado     52                12
# 2               RH  Masculino             Mestrado     54                12
# 3       Financeiro   Feminino             Mestrado     32                 9
# 4               RH  Masculino  Superior Incompleto     34                 8
# ..             ...        ...                  ...    ...               ...
# 10       Marketing  Masculino    Superior Completo     35                 8
# 11       Marketing  Masculino             Mestrado     50                14
# 12  Administrativo  Masculino    Superior Completo     63                 8
# 13  Administrativo  Masculino    Superior Completo     61                 9
# 14      Financeiro   Feminino            Doutorado     36                 8
#
#    Estado       Salario
# 0      SP   2708.410161
# ...

# %%
tabela_salario
# Out:
#             Setor       Salario
# 0  Administrativo  2.248535e+06
# 1      Financeiro  8.967006e+05
# 2       Marketing  9.669023e+05
# 3        Operacao  3.545110e+06
# 4              RH  1.048478e+06

# %%
setor_adm = df_df[ df_df.Setor == 'Administrativo' ].drop(columns='Setor').reset_index(drop=True)
setor_adm
# Out:
#           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
# 0    Masculino             Mestrado     32                 9     SP
# 1    Masculino    Superior Completo     47                15     RJ
# 2    Masculino    Superior Completo     47                15     SP
# 3    Masculino    Superior Completo     56                11     SP
# 4    Masculino             Mestrado     32                 9     BH
# ..         ...                  ...    ...               ...    ...
# 398  Masculino            Doutorado     72                 7     SP
# 399   Feminino    Superior Completo     31                 9     RJ
# 400   Feminino  Superior Incompleto     46                15     SP
# 401  Masculino    Superior Completo     63                 8     SP
# 402  Masculino    Superior Completo     61                 9     SP
#
#           Salario
# 0     6948.868398
# 1     8687.786858
# 2     7914.972759
# 3     5595.857117
# 4     6802.579902
# ..            ...
# ...

# %%
setor_fin = df_df[ df_df.Setor == 'Financeiro' ].drop(columns='Setor').reset_index(drop=True)
setor_fin
# Out:
#           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
# 0     Feminino             Mestrado     32                 9     BH
# 1    Masculino    Superior Completo     65                 8     SP
# 2     Feminino  Superior Incompleto     63                 8     SP
# 3    Masculino    Superior Completo     47                15     BH
# 4    Masculino            Doutorado     55                 8     SP
# ..         ...                  ...    ...               ...    ...
# 174   Feminino  Superior Incompleto     50                13     SP
# 175   Feminino  Superior Incompleto     66                 7     SP
# 176  Masculino    Superior Completo     54                12     BH
# 177  Masculino    Superior Completo     41                17     SP
# 178   Feminino            Doutorado     36                 8     SP
#
#           Salario
# 0     6512.599657
# 1     2024.994882
# 2     2038.753298
# 3     2818.107045
# 4     9553.051933
# ..            ...
# ...

# %%
setor_mkt = df_df[ df_df.Setor == 'Marketing' ].drop(columns='Setor').reset_index(drop=True)
setor_mkt
# Out:
#           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
# 0    Masculino    Superior Completo     31                 9     SP
# 1    Masculino  Superior Incompleto     40                17     SP
# 2     Feminino  Superior Incompleto     37                13     RJ
# 3     Feminino    Superior Completo     47                15     BH
# 4     Feminino    Superior Completo     52                13     SP
# ..         ...                  ...    ...               ...    ...
# 187  Masculino    Superior Completo     40                17     SP
# 188  Masculino    Superior Completo     61                 9     BH
# 189   Feminino    Superior Completo     47                15     SP
# 190  Masculino    Superior Completo     35                 8     SP
# 191  Masculino             Mestrado     50                14     SP
#
#          Salario
# 0    6275.597489
# 1    2104.902227
# 2    2014.408523
# 3    7990.101936
# 4    4418.462731
# ..           ...
# 187  5139.437521
# ...

# %%
setor_opr = df_df[ df_df.Setor == 'Operacao' ].drop(columns='Setor').reset_index(drop=True)
setor_opr
# Out:
#           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado  \
# 0    Masculino    Superior Completo     54                12     SP
# 1    Masculino    Superior Completo     52                13     BH
# 2     Feminino    Superior Completo     38                12     SP
# 3    Masculino             Mestrado     45                16     SP
# 4    Masculino  Superior Incompleto     40                17     SP
# ..         ...                  ...    ...               ...    ...
# 552  Masculino    Superior Completo     56                11     SP
# 553  Masculino            Doutorado     45                16     BH
# 554  Masculino    Superior Completo     51                13     SP
# 555   Feminino  Superior Incompleto     43                16     RJ
# 556  Masculino    Superior Completo     44                16     RJ
#
#           Salario
# 0     2708.410161
# 1     1368.040623
# 2    10497.986350
# 3     6488.446200
# 4     5674.497590
# ..            ...
# ...

# %%
setor_rh = df_df[ df_df.Setor == 'RH' ].drop(columns='Setor').reset_index(drop=True)
setor_rh
# Out:
#           Sexo       Grau_Instrucao  Idade  Anos_Experiencia Estado   Salario
# 0    Masculino            Doutorado     52                12     SP  8321.204
# 1    Masculino             Mestrado     54                12     RJ  7588.139
# 2    Masculino  Superior Incompleto     34                 8     BH  3125.765
# 3     Feminino             Mestrado     66                 8     RJ  7878.497
# 4     Feminino    Superior Completo     68                 7     SP  6815.129
# ..         ...                  ...    ...               ...    ...       ...
# 184  Masculino  Superior Incompleto     28                 5     SP  3046.940
# 185  Masculino    Superior Completo     34                 8     SP  6603.683
# 186   Feminino    Superior Completo     46                15     SP  5359.789
# 187   Feminino  Superior Incompleto     53                12     SP  3583.467
# 188  Masculino    Superior Completo     58                10     BH  6538.568
#
# [189 rows x 6 columns]

# %% [markdown]
# #Exercicio 1

# %%
setor_adm.memory_usage()
# Out:
# Index                128
# Sexo                3224
# Grau_Instrucao      3224
# Idade               3224
# Anos_Experiencia    3224
# Estado              3224
# Salario             3224
# dtype: int64

# %%
setor_adm.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sexo              403 non-null    object
#  1   Grau_Instrucao    403 non-null    object
#  2   Idade             403 non-null    int64
#  3   Anos_Experiencia  403 non-null    int64
#  4   Estado            403 non-null    object
#  5   Salario           403 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 87.1 KB

# %%
setor_adm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sexo              403 non-null    object
#  1   Grau_Instrucao    403 non-null    object
#  2   Idade             403 non-null    int64
#  3   Anos_Experiencia  403 non-null    int64
#  4   Estado            403 non-null    object
#  5   Salario           403 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 19.0+ KB

# %%
setor_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sexo              179 non-null    object
#  1   Grau_Instrucao    179 non-null    object
#  2   Idade             179 non-null    int64
#  3   Anos_Experiencia  179 non-null    int64
#  4   Estado            179 non-null    object
#  5   Salario           179 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 8.5+ KB

# %%
print("O adm tem 19.0 KB e o fin tem 8.5 KB")
# Out:
# O adm tem 19.0 KB e o fin tem 8.5 KB

# %% [markdown]
# #Exercicio 2

# %%
setor_adm.to_csv('adm.csv', sep=',', index=False)

# %%
setor_fin.to_csv('fin.csv', sep=',', index=False)

# %%
json_adm = setor_adm.to_json('adm.json')

# %%
json_fin = setor_fin.to_json('fin.json')

# %% [markdown]
# #Exercicio 3

# %%
moda_adm = setor_adm['Salario'].mode()
moda_adm
# Out:
# 0       1283.716170
# 1       1311.246994
# 2       1608.094683
# 3       1812.824022
# 4       1828.749717
#            ...
# 398    17306.150000
# 399    17578.020000
# 400    17945.620000
# 401    18097.530000
# 402    19790.410000
# Name: Salario, Length: 403, dtype: float64

# %%
media_adm = setor_adm['Salario'].mean()
media_adm
# Out:
# 5579.490246096774

# %%
moda_fin = setor_fin['Salario'].mode()
moda_fin
# Out:
# 0       1682.532796
# 1       1822.719418
# 2       1829.038381
# 3       1831.617734
# 4       1846.353416
#            ...
# 174    11095.959040
# 175    11100.825170
# 176    11344.365450
# 177    11825.479150
# 178    11837.969370
# Name: Salario, Length: 179, dtype: float64

# %%
media_fin = setor_fin['Salario'].mean()
media_fin
# Out:
# 5009.500543312849

# %%
moda_mkt = setor_mkt['Salario'].mode()
moda_mkt
# Out:
# 0       1294.761744
# 1       1373.282813
# 2       1491.025577
# 3       1563.949684
# 4       1584.101233
#            ...
# 187    11331.071640
# 188    11398.338180
# 189    11409.298110
# 190    11571.479090
# 191    11797.855780
# Name: Salario, Length: 192, dtype: float64

# %%
media_mkt = setor_mkt['Salario'].mean()
media_mkt
# Out:
# 5035.949556890625

# %%
moda_opr = setor_opr['Salario'].mode()
moda_opr
# Out:
# 0       1253.726734
# 1       1292.339494
# 2       1307.153449
# 3       1362.232033
# 4       1368.040623
#            ...
# 552    11905.529150
# 553    11910.849820
# 554    12048.298640
# 555    12085.552150
# 556    12406.652060
# Name: Salario, Length: 557, dtype: float64

# %%
media_opr = setor_opr['Salario'].mean()
media_opr
# Out:
# 6364.649269324955

# %%
moda_rh = setor_rh['Salario'].mode()
moda_rh
# Out:
# 0       2744.818
# 1       2790.871
# 2       2810.377
# 3       2835.662
# 4       2836.296
#          ...
# 184     8414.703
# 185     8802.473
# 186     8991.566
# 187     9465.429
# 188    10189.237
# Name: Salario, Length: 189, dtype: float64

# %%
media_rh = setor_rh['Salario'].mean()
media_rh
# Out:
# 5547.5012486772475

# %% [markdown]
# #Exercicio 4

# %%
setor_adm['Grau_Instrucao'].unique()
# Out:
# array(['Mestrado', 'Superior Completo', 'Superior Incompleto',
#        'Doutorado'], dtype=object)

# %%
setores = [setor_adm, setor_fin, setor_mkt, setor_opr, setor_rh]

graus = {'Doutorado': 1, 'Mestrado': 2, 'Superior Completo': 3, 'Superior Incompleto': 4}

for setor in setores:
  print(setor['Grau_Instrucao'].map(graus).sum())
# Out:
# 1179
# 538
# 573
# 1628
# 580

# %%
sum([1179, 538, 573, 1628, 580])
# Out:
# 4498

# %% [markdown]
# #Exercicio 5

# %%
df_df
# Out:
#              Setor       Sexo       Grau_Instrucao  Idade  Anos_Experiencia  \
# 0         Operacao  Masculino    Superior Completo     54                12
# 1               RH  Masculino            Doutorado     52                12
# 2               RH  Masculino             Mestrado     54                12
# 3       Financeiro   Feminino             Mestrado     32                 9
# 4               RH  Masculino  Superior Incompleto     34                 8
# ..             ...        ...                  ...    ...               ...
# 10       Marketing  Masculino    Superior Completo     35                 8
# 11       Marketing  Masculino             Mestrado     50                14
# 12  Administrativo  Masculino    Superior Completo     63                 8
# 13  Administrativo  Masculino    Superior Completo     61                 9
# 14      Financeiro   Feminino            Doutorado     36                 8
#
#    Estado       Salario
# 0      SP   2708.410161
# ...

# %%
crosstab_setores = pd.crosstab(df_df['Sexo'], df_df['Setor'])
crosstab_setores
# Out:
# Setor      Administrativo  Financeiro  Marketing  Operacao   RH
# Sexo
# Feminino              163          72         66       221   72
# Masculino             240         107        126       336  117

# %%
m_mkt = 66 / 126
m_mkt
# Out:
# 0.5238095238095238

# %%
crosstab_setores.sum()
# Out:
# Setor
# Administrativo    403
# Financeiro        179
# Marketing         192
# Operacao          557
# RH                189
# dtype: int64

# %%
sum([403, 179, 192, 557, 189])
# Out:
# 1520

# %%
m_empresa = 66 / 1520
m_empresa
# Out:
# 0.04342105263157895

# %%
print(f'{m_empresa * 100 :.1f} %')
# Out:
# 4.3 %

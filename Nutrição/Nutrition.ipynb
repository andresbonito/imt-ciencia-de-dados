# %% [markdown]
# #Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #Arquivos

# %%
food = pd.read_csv('food.csv')
food1 = pd.read_csv('food1.csv')

# %% [markdown]
# ##Food

# %%
food
# Out:
#         Category                 Description  Nutrient Data Bank Number  \
# 0         BUTTER            BUTTER,WITH SALT                       1001
# 1         BUTTER    BUTTER,WHIPPED,WITH SALT                       1002
# 2     BUTTER OIL        BUTTER OIL,ANHYDROUS                       1003
# 3         CHEESE                 CHEESE,BLUE                       1004
# 4         CHEESE                CHEESE,BRICK                       1005
# ...          ...                         ...                        ...
# 7408   FROG LEGS               FROG LEGS,RAW                      80200
# 7409    MACKEREL             MACKEREL,SALTED                      83110
# 7410     SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD                      90240
# 7411       SNAIL                   SNAIL,RAW                      90560
# 7412      TURTLE            TURTLE,GREEN,RAW                      93600
#
#       Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  \
# ...

# %% [markdown]
# ##Food 1

# %%
food1
# Out:
#         Category                 Description  Nutrient Data Bank Number  \
# 0         BUTTER            BUTTER,WITH SALT                       1001
# 1         BUTTER    BUTTER,WHIPPED,WITH SALT                       1002
# 2     BUTTER OIL        BUTTER OIL,ANHYDROUS                       1003
# 3         CHEESE                 CHEESE,BLUE                       1004
# 4         CHEESE                CHEESE,BRICK                       1005
# ...          ...                         ...                        ...
# 7408   FROG LEGS               FROG LEGS,RAW                      80200
# 7409    MACKEREL             MACKEREL,SALTED                      83110
# 7410     SCALLOP  SCALLOP,(BAY&SEA),CKD,STMD                      90240
# 7411       SNAIL                   SNAIL,RAW                      90560
# 7412      TURTLE            TURTLE,GREEN,RAW                      93600
#
#       Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  \
# ...

# %% [markdown]
# #Estudo

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ff43dbf558f0> in <module>
# ----> 1 food.groupby('Category').get_groups()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'get_groups'
